# %%
import matplotlib.pyplot as plt
import pandas as pd
from data_processing.cgm_data import CGMData
from data_processing.cgm_data_helper import plot_series_with_food,plot_series_with_diff

# %%
data = CGMData()

# %%
differences = data[2].glu.diff(2)

plt.figure(figsize=(20, 4))
plt.plot(differences[(differences.index < '2020-02-22 23:00:00') & (differences.index > '2020-02-22 03:00:00')])

# %%
data

# %%
food2 = pd.read_csv('./data/002/Food_Log_002.csv', index_col=['time_begin'], parse_dates=['time_begin'], skipinitialspace=True)
glu2 = pd.read_csv('./data/002/Dexcom_002.csv', header=0, skiprows=range(1, 13), index_col=['Timestamp (YYYY-MM-DDThh:mm:ss)'], parse_dates=['Timestamp (YYYY-MM-DDThh:mm:ss)'])

# %%
plot_series_with_food(glu2, food2, '2020-02-22', '2020-02-22', 'Glucose Value (mg/dL)')

# %%
plot_series_with_diff(glu2, food2, '2020-02-22', '2020-02-22')
