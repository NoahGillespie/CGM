# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

color_pal = sns.color_palette()
## import xgboost as xgb

# %%
## Acc
pd.read_csv('/kaggle/input/acc-001-data/ACC_001.csv')
# Out:
#                             datetime   acc_x   acc_y   acc_z
# 0         2020-02-13 15:28:50.000000   -34.0    17.0    55.0
# 1         2020-02-13 15:28:50.031250   -34.0    17.0    52.0
# 2         2020-02-13 15:28:50.062500   -34.0    19.0    51.0
# 3         2020-02-13 15:28:50.093750   -36.0    18.0    51.0
# 4         2020-02-13 15:28:50.125000   -35.0    17.0    52.0
# ...                              ...     ...     ...     ...
# 20296423  2020-02-22 17:56:03.718750     5.0    -6.0    65.0
# 20296424  2020-02-22 17:56:03.750000     6.0    -6.0    61.0
# 20296425  2020-02-22 17:56:03.781250     3.0    -4.0    64.0
# 20296426  2020-02-22 17:56:03.812500     5.0    -4.0    66.0
# 20296427  2020-02-22 17:56:03.843750     4.0    -7.0    66.0
#
# [20296428 rows x 4 columns]

# %%
## Food
pd.read_csv('/kaggle/input/food-log-001-data/Food_Log_001.csv')
# Out:
#           date      time           time_begin  time_end  \
# 0   2020-02-13  18:00:00  2020-02-13 18:00:00       NaN
# 1   2020-02-13  20:30:00  2020-02-13 20:30:00       NaN
# 2   2020-02-13  20:30:00  2020-02-13 20:30:00       NaN
# 3   2020-02-14  07:10:00  2020-02-14 07:10:00       NaN
# 4   2020-02-14  07:10:00  2020-02-14 07:10:00       NaN
# ..         ...       ...                  ...       ...
# 56  2020-02-21  12:30:00  2020-02-21 12:30:00       NaN
# 57  2020-02-21  12:30:00  2020-02-21 12:30:00       NaN
# 58  2020-02-21  19:50:00  2020-02-21 19:50:00       NaN
# 59  2020-02-21  20:00:00  2020-02-21 20:00:00       NaN
# 60  2020-02-22  15:10:00  2020-02-22 15:10:00       NaN
#
#                       logged_food  amount         unit  \
# 0                  Berry Smoothie   20.00  fluid ounce
# 1                     Chicken Leg    1.00          NaN
# 2                       Asparagus    4.00          NaN
# 3   Natrel Lactose Free 2 Percent    8.00  fluid ounce
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot()
# Out:
# []

# %%
pd.read_csv('/kaggle/input/dexcom-001/Dexcom_001.csv')
# Out:
#       Index Timestamp (YYYY-MM-DDThh:mm:ss)         Event Type Event Subtype  \
# 0         1                             NaN          FirstName           NaN
# 1         2                             NaN           LastName           NaN
# 2         3                             NaN  PatientIdentifier           NaN
# 3         4                             NaN        DateOfBirth           NaN
# 4         5                             NaN             Device           NaN
# ...     ...                             ...                ...           ...
# 2568   2569             2020-02-22 17:33:23                EGV           NaN
# 2569   2570             2020-02-22 17:38:23                EGV           NaN
# 2570   2571             2020-02-22 17:43:23                EGV           NaN
# 2571   2572             2020-02-22 17:48:22                EGV           NaN
# 2572   2573             2020-02-22 17:53:23                EGV           NaN
#
# ...

# %%
df.plot(style='.', figsize=(20, 4),
         color=color_pal[0], 
         title='Dexcom')
plt.show()

# %%
## Temperature
df = pd.read_csv('/kaggle/input/temp-001/TEMP_001.csv')
df = df.set_index('datetime')
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex([       '2020-02-13 15:28:50', '2020-02-13 15:28:50.250000',
#                '2020-02-13 15:28:50.500000', '2020-02-13 15:28:50.750000',
#                       '2020-02-13 15:28:51', '2020-02-13 15:28:51.250000',
#                '2020-02-13 15:28:51.500000', '2020-02-13 15:28:51.750000',
#                       '2020-02-13 15:28:52', '2020-02-13 15:28:52.250000',
#                ...
#                '2020-02-22 17:56:01.500000', '2020-02-22 17:56:01.750000',
#                       '2020-02-22 17:56:02', '2020-02-22 17:56:02.250000',
#                '2020-02-22 17:56:02.500000', '2020-02-22 17:56:02.750000',
#                       '2020-02-22 17:56:03', '2020-02-22 17:56:03.250000',
#                '2020-02-22 17:56:03.500000', '2020-02-22 17:56:03.750000'],
#               dtype='datetime64[ns]', name='datetime', length=2537040, freq=None)

# %%
df.plot(style='.', figsize=(20, 5),
         color=color_pal[0], 
         title='Temp001 in Degree Celsius')
plt.show()

# %%
##Maybe we should remove the outliers-(sensor problem)
## Missing data point

# %%
## Train / Test Split
## Splitting at 2020-02-19

train = df.loc[df.index <'2020-02-19']
test = df.loc[df.index >='2020-02-19']

fig, ax= plt.subplots(figsize=(20, 5))
train.plot(ax=ax, label='Training set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test set')
ax.axvline('2020-02-19', color='black', ls='--')
ax.legend(['Training set', 'Test set'])
plt.show()

# %%
## One week of data 
df.loc[(df.index >'2020-02-18') & (df.index < '2020-02-25')].plot(figsize=(20,5), title='Week of Data')
plt.show()

# %%
def create_features(df):
    """Create time series features based on time series index.
    """
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    return df

df = create_features(df)

# %%
#fig, ax = plt.subplots(figsize=(10.5))
#sns.boxplot(data=df, x='hour', y='temp' pallete = 'red')
#ax.set_title('temp hour')
#plt.show()

# %%
#fig, ax = plt.subplots(figsize=(10.5))
#sns.boxplot(data=df, x='hour', y='temp' pallete = 'blue')
#ax.set_title('temp month')
#plt.show()
